# %% [markdown]
# <a href="https://colab.research.google.com/github/hardiksharma6555/MLP_code/blob/main/MLP_OPE_1_21f1006555.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Q. 1: Which dataset are you using for this exam?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyplot
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c9fc2da7-4769-4606-bca8-b604a45c41bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9fc2da7-4769-4606-bca8-b604a45c41bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('V1.csv')

# %%
data.shape
# Out:
# (1000, 13)

# %% [markdown]
# ###Q.2:How many total number of features (Excluding target variable) are there in the dataset?

# %%
data.describe()
# Out:
#               team  targeted_productivity          smv           wip  \
# count  1000.000000            1000.000000  1000.000000    586.000000
# mean      6.387000               0.727800    15.263220   1155.825939
# std       3.448641               0.097861    10.945742   1561.374068
# min       1.000000               0.350000     2.900000      7.000000
# 25%       3.000000               0.700000     3.940000    776.750000
# 50%       6.000000               0.750000    15.260000   1039.000000
# 75%       9.000000               0.800000    24.260000   1254.750000
# max      12.000000               0.800000    54.560000  21540.000000
#
#           over_time   incentive    idle_time    idle_men  no_of_style_change  \
# count   1000.000000  1000.00000  1000.000000  1000.00000         1000.000000
# mean    4613.840000    39.94800     0.769500     0.35700            0.156000
# std     3374.263899   172.17795    13.610873     3.27143            0.435722
# ...

# %% [markdown]
# ### Q. 3:Which of the following column have missing values ?

# %%
data.head()
# Out:
#         date  department  team  targeted_productivity    smv     wip  \
# 0  2/23/2015   finishing    12                    0.8   5.13     NaN
# 1   3/7/2015      sweing     3                    0.8  29.40   983.0
# 2  2/16/2015      sweing     9                    0.6  18.79  2103.0
# 3  1/11/2015  finishing      6                    0.8   2.90     NaN
# 4  2/17/2015   finishing     3                    0.5   5.13     NaN
#
#    over_time  incentive  idle_time  idle_men  no_of_style_change  \
# 0       1080          0        0.0         0                   0
# 1       6840         63        0.0         0                   1
# 2       5400          0        0.0         0                   1
# 3       1440          0        0.0         0                   0
# 4       1800          0        0.0         0                   0
#
#    no_of_workers  actual_productivity
# 0            9.0             0.902500
# 1           57.0             0.800579
# 2           54.0             0.329965
# ...

# %% [markdown]
# ### Q. 4:What are the unique department mentioned in the dataset?

# %%
#finishing and sweing are unique

# %%
data.shape
# Out:
# (1000, 13)

# %% [markdown]
# ### Q. 5:Which of the following columns have categorical data

# %%
# Out:
#           date  department  team  targeted_productivity    smv     wip  \
# 0    2/23/2015   finishing    12                    0.8   5.13     NaN
# 1     3/7/2015      sweing     3                    0.8  29.40   983.0
# 2    2/16/2015      sweing     9                    0.6  18.79  2103.0
# 3    1/11/2015  finishing      6                    0.8   2.90     NaN
# 4    2/17/2015   finishing     3                    0.5   5.13     NaN
# ..         ...         ...   ...                    ...    ...     ...
# 995  2/11/2015   finishing     5                    0.7   4.15     NaN
# 996  1/27/2015  finishing     10                    0.8   3.94     NaN
# 997   2/9/2015      sweing     3                    0.8  22.52  1271.0
# 998  2/17/2015   finishing    12                    0.8   5.13     NaN
# 999   2/8/2015   finishing     2                    0.8   3.94     NaN
#
#      over_time  incentive  idle_time  idle_men  no_of_style_change  \
# ...

# %% [markdown]
# ### Q. 6:Replace all NaN value in "wip" column by 0 and Check how many outliers are there in "incentive" column (Consider any incentive value >1000 as outlier) ?

# %%
#checked using boxplot

# %% [markdown]
# ### Q. 7:Break the dataset into X and y, where the column "actual_productivity" goes to y and rest of the columns go to X. Enter the avg value of "actual_productivity" column?

# %%
y = data.loc[:,'actual_productivity']
X = data.drop(['actual_productivity'],axis =1)

# %%
X
# Out:
#           date  department  team  targeted_productivity    smv     wip  \
# 0    2/23/2015   finishing    12                    0.8   5.13     NaN
# 1     3/7/2015      sweing     3                    0.8  29.40   983.0
# 2    2/16/2015      sweing     9                    0.6  18.79  2103.0
# 3    1/11/2015  finishing      6                    0.8   2.90     NaN
# 4    2/17/2015   finishing     3                    0.5   5.13     NaN
# ..         ...         ...   ...                    ...    ...     ...
# 995  2/11/2015   finishing     5                    0.7   4.15     NaN
# 996  1/27/2015  finishing     10                    0.8   3.94     NaN
# 997   2/9/2015      sweing     3                    0.8  22.52  1271.0
# 998  2/17/2015   finishing    12                    0.8   5.13     NaN
# 999   2/8/2015   finishing     2                    0.8   3.94     NaN
#
#      over_time  incentive  idle_time  idle_men  no_of_style_change  \
# ...

# %%
y
# Out:
# 0      0.902500
# 1      0.800579
# 2      0.329965
# 3      0.597348
# 4      0.786600
#          ...
# 995    0.870000
# 996    0.979528
# 997    0.800161
# 998    0.902500
# 999    0.875556
# Name: actual_productivity, Length: 1000, dtype: float64

# %%
sns.boxplot(x=X["wip"])

# %%
sns.violinplot(x=X["wip"])

# %%
y.mean()
# Out:
# 0.732390698357

# %% [markdown]
# ### Q. 8:Plot the heatmap and mark the pair which has highest correlation value.

# %%
from sklearn.model_selection import train_test_split
X_train, x_test, y_train, y_test = train_test_split(X,y,train_size=0.3,random_state=42)

# %%
X_train.shape
# Out:
# (300, 12)

# %%
x_test.shape
# Out:
# (700, 12)

# %% [markdown]
# ### Q. 9:
# 5 points
# Common Instructions for Question 9 and 10
#
# Step 1: Drop the date column from X data.
#
# Step 2: We can see in "department" column  wrong spelling of "Sewing" is given. Update it to "Sewing" in X dataset.
#
# Step 3: At some places in "department" column "finishing" variable is written with an extra space So, replace "finishing " with "finishing" in X dataset.
#
#
# Step 4 Use pd.getdummies to encode all  categorical features of X dataset.
#
# What is the total number of  "finishing" label in department column of X dataset?

# %%
X = data.drop(['date'],axis =1)

# %%
X
# Out:
#      department  team  targeted_productivity    smv     wip  over_time  \
# 0     finishing    12                    0.8   5.13     NaN       1080
# 1        sweing     3                    0.8  29.40   983.0       6840
# 2        sweing     9                    0.6  18.79  2103.0       5400
# 3    finishing      6                    0.8   2.90     NaN       1440
# 4     finishing     3                    0.5   5.13     NaN       1800
# ..          ...   ...                    ...    ...     ...        ...
# 995   finishing     5                    0.7   4.15     NaN        240
# 996  finishing     10                    0.8   3.94     NaN       1440
# 997      sweing     3                    0.8  22.52  1271.0       5400
# 998   finishing    12                    0.8   5.13     NaN       1080
# 999   finishing     2                    0.8   3.94     NaN       2160
#
#      incentive  idle_time  idle_men  no_of_style_change  no_of_workers  \
# ...

# %%
X.department

# %% [markdown]
# ### Q. 10:What is the total number of columns in X dataset now?

# %% [markdown]
# ### Q. 11:Split the dataset into training and test dataset using train test split into `70:30` ratio while keeping `random_state =32`. what is the shape of the `X_train` dataset?

# %%
from sklearn

# %% [markdown]
# ### Q. 12:
# 5 points
# Apply LinearRegression on the 'x_train' and 'y_train' data. Calculate the score on the 'x_test' and 'y_test'. Which of the following options represent the calculated R^2R
# 2
#   score.

# %% [markdown]
# ### Q. 13:Using the Linear regression model, compute the cross-validation scores for 9 splits on training data (x_train and y_train) using cross_val_score.Enter the maximum value of R^2R
# 2
#   score obtained upto four decimal places.
#
# (Hint: By default `cross_val_score` uses `LinearRegression`'s scoring metric, which is R^2R
# 2

# %%
from sklearn.metrics import r2_score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-b70f62d33123> in <module>
# ----> 1 dummy_regr = Dummy_Regressor(strategy = "mean")
#       2 dummy_regr.fit = (X_train,y_train)
#       3 dummy_regr.predict = (x_test,y_test)
#       4 dummy_regr.score =  x_test
#
# NameError: name 'Dummy_Regressor' is not defined

# %% [markdown]
# ### Q. 14:Apply `SequentialFeatureSelector` with `LinearRegression()` estimator and select 5 features by fitting to the `x_train` and `y_train`. Which of the following option represents the correct integer index, of the selected features list??

# %%
data.describe()
# Out:
#               team  targeted_productivity          smv           wip  \
# count  1000.000000            1000.000000  1000.000000    586.000000
# mean      6.387000               0.727800    15.263220   1155.825939
# std       3.448641               0.097861    10.945742   1561.374068
# min       1.000000               0.350000     2.900000      7.000000
# 25%       3.000000               0.700000     3.940000    776.750000
# 50%       6.000000               0.750000    15.260000   1039.000000
# 75%       9.000000               0.800000    24.260000   1254.750000
# max      12.000000               0.800000    54.560000  21540.000000
#
#           over_time   incentive    idle_time    idle_men  no_of_style_change  \
# count   1000.000000  1000.00000  1000.000000  1000.00000         1000.000000
# mean    4613.840000    39.94800     0.769500     0.35700            0.156000
# std     3374.263899   172.17795    13.610873     3.27143            0.435722
# ...

# %% [markdown]
# ### Q. 15:Take SelectKBest feature selector with k=5 and mutual_info_regression as scoring function and fit it to training data(x_train and y_train), then transform it.Which of the following options represent the 5 selected features using above instructions?

# %%
RidgeCV(alphas= [0.1,0.01,1,0.005]).fit(X, y)

# %% [markdown]
# ### Q. 16:
# 4 points
# Apply Ridge regression `Ridge()` with default penalty value on `x_train` and `y_train` and calculate the R^2R
# 2
#   score on `x_train` and `y_train`. Which of the following options represents the correct score (Upto 4 digits after decimal points)?

# %% [markdown]
# ### Q. 17:Apply Lasso regression with alpha=0.1 on the training data. Enter the value of the intercept you got correctly upto 4 digits after decimal points

# %% [markdown]
# ### Q. 18:Fit SGDRegressor() estimator with random_state=32 on the training data and predict actual_productivity (y_test) for test data. The parameters are initialized with default values. Calculate and mark the correct mean_squared_error value between y_test and predicted y_test from the given options.

# %% [markdown]
# ### Q. 19:
# 7 points
# Apply cross validation strategy on training data using SGDRegressor(random_state=32) as an estimator and cv= ShuffleSplit. Set paramters for ShuffleSplit as following:
#
# n_split to be taken as 8.
# test_size to be taken as 40%.
# random_state value to be taken as 32
#
# Mark the correct mean value of cross_val_score obtained upto four decimal places from the given options.

# %%
import sklearn

# %% [markdown]
# ### Q. 20:Create a pipeline Using PolynomialFeatures as transformer and Lasso as estimator. Use GridSearchCV with this created pipeline and following hyperparameter values on training data(x_train, y_train) to fit the model .
# i) Keep polynomial degree as : [1, 2, 3]
#
# ii) alpha value to be taken as : np.logspace(-3, 0, num=8)
#
# iii) scoring : neg_mean_absolute_error .
#
# (Note: Kindly ignore the warning.)
#
# Enter the best alpha value you got using above instructions.(Upto 4 decimal places)

# %% [markdown]
# ### Q. 21:
# Enter the best polynomial degree value you got using above instructions.

# %% [markdown]
# ### Q. 22:Fit the PCA model using following parameter values on training data and apply the dimensionality reduction on it(training data).
#
# n_components=5
# svd_solver='full'
# whiten=True
# random_state=32
#
# What is the sum of explained variance ratio corresponding to each of the selected components

# %% [markdown]
# ### Q. 23:Use this transformed training data and y_train to fit the RidgeCV estimator model having alpha value as [0.1,0.01,1,0.005] .Enter the best_score_ value you got for this model.
